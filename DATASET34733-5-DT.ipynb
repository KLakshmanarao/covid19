# %%
# importing libraries 
import numpy as np 
import pandas as pd 
import math 
import random 
#import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Initilization of 
# Data set

# defining the columns using normal distribution 
# np.random.randint(0, 2, 5) --> To produces 5 numbers. Each no is either 0 or 1 
# column 1  Symptom-I
cold = np.zeros((119711,), dtype=int)
# column 2  Symptom2
cough = np.zeros((119711,), dtype=int)
# column 3 Symptom3
feaver = np.zeros((119711,), dtype=int)
# column 4 Symptom4
breating = np.zeros((119711,), dtype=int)
# Column 5 Symptom 5
cronic = np.zeros((119711,), dtype=int)
# Column 6 
age = np.zeros((119711,), dtype=int) #
#Column 7 The output either Covid-19 or NON-Covid
#disease = np.random.randint(1, 10, 500)
disease = np.full(119711,'No  Symptom',dtype='object')

# %%
#General Symptoms(GS) are 321. It is multiplied with 7. Hence, 321*7=2247
b=0
for i in range(0,2247):  #This is to fill General Symptoms  (GS-->1 in disease column)
    b=b+1
    if(b==1):
        cold[i]=0
        cough[i]=0
        feaver[i]=1
        breating[i]=0
        cronic[i]=0
        age[i]=0  # age=0 indicates that age not considered it may be of any age
        disease[i]="GS"
    if(b==2):
        cold[i]=0
        cough[i]=1
        feaver[i]=0
        breating[i]=0
        cronic[i]=0
        age[i]=0
        disease[i]="GS"
    if(b==3):
        cold[i]=0
        cough[i]=1
        feaver[i]=1
        breating[i]=0
        cronic[i]=0
        age[i]=0
        disease[i]="GS"
    if(b==4):
        cold[i]=1
        cough[i]=0
        feaver[i]=0
        breating[i]=0
        cronic[i]=0
        age[i]=0
        disease[i]="GS"
    if(b==5):
        cold[i]=1
        cough[i]=0
        feaver[i]=1
        breating[i]=0
        cronic[i]=0
        age[i]=0
        disease[i]="GS"
    if(b==6):
        cold[i]=1
        cough[i]=1
        feaver[i]=0
        breating[i]=0
        cronic[i]=0
        age[i]=0
        disease[i]="GS"
    if(b==7):
        cold[i]=1
        cough[i]=1
        feaver[i]=1
        breating[i]=0
        cronic[i]=0
        age[i]=0
        disease[i]="GS"
    if(b==7):
        b=1

# %%
# HR1 is 116. It is multiplied with 16. Hence, 116*16=1856. It is from 2247+1856=4103
b=0
for i in range(2247,4215):  #This is to fill   (HR1-->2 in disease column) or Low Risk
    b=b+1
    if(b==1):
        cold[i]=0
        cough[i]=0
        feaver[i]=0
        breating[i]=1
        cronic[i]=0
        age[i]=1        # age=1 indicates that age > 60
        disease[i]="Low Risk"
    if(b==2):
        cold[i]=0
        cough[i]=0
        feaver[i]=1
        breating[i]=0
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==3):
        cold[i]=0
        cough[i]=1
        feaver[i]=0
        breating[i]=1
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==4):
        cold[i]=0
        cough[i]=1
        feaver[i]=0
        breating[i]=0
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==5):
        cold[i]=0
        cough[i]=1
        feaver[i]=0
        breating[i]=1
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==6):
        cold[i]=0
        cough[i]=1
        feaver[i]=1
        breating[i]=0
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==7):
        cold[i]=0
        cough[i]=1
        feaver[i]=1
        breating[i]=1
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==8):
        cold[i]=1
        cough[i]=0
        feaver[i]=0
        breating[i]=0
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==9):
        cold[i]=1
        cough[i]=0
        feaver[i]=0
        breating[i]=1
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==10):
        cold[i]=1
        cough[i]=0
        feaver[i]=1
        breating[i]=0
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==11):
        cold[i]=1
        cough[i]=0
        feaver[i]=1
        breating[i]=1
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==12):
        cold[i]=1
        cough[i]=1
        feaver[i]=0
        breating[i]=0
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==13):
        cold[i]=1
        cough[i]=1
        feaver[i]=0
        breating[i]=1
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==14):
        cold[i]=1
        cough[i]=1
        feaver[i]=1
        breating[i]=0
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==15):
        cold[i]=1
        cough[i]=1
        feaver[i]=1
        breating[i]=1
        cronic[i]=0
        age[i]=1
        disease[i]="Low Risk"
    if(b==15):
        b=1

# %%
# HR2 is 67. It is multiplied with 16. Hence, 67*16=1072. It is from 4103+1072=5175
b=0
for i in range(4215,5287):  #This is to fill   (HR2-->3 in disease column) or Medium Risk
    b=b+1
    if(b==1):
        cold[i]=0
        cough[i]=0
        feaver[i]=0
        breating[i]=1
        cronic[i]=1
        age[i]=2           #2 indicates that the age is <60
        disease[i]="Medium Risk"
    if(b==2):
        cold[i]=0
        cough[i]=0
        feaver[i]=1
        breating[i]=0
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==3):
        cold[i]=0
        cough[i]=1
        feaver[i]=0
        breating[i]=1
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==4):
        cold[i]=0
        cough[i]=1
        feaver[i]=0
        breating[i]=0
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==5):
        cold[i]=0
        cough[i]=1
        feaver[i]=0
        breating[i]=1
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==6):
        cold[i]=0
        cough[i]=1
        feaver[i]=1
        breating[i]=0
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==7):
        cold[i]=0
        cough[i]=1
        feaver[i]=1
        breating[i]=1
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==8):
        cold[i]=1
        cough[i]=0
        feaver[i]=0
        breating[i]=0
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==9):
        cold[i]=1
        cough[i]=0
        feaver[i]=0
        breating[i]=1
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==10):
        cold[i]=1
        cough[i]=0
        feaver[i]=1
        breating[i]=0
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==11):
        cold[i]=1
        cough[i]=0
        feaver[i]=1
        breating[i]=1
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==12):
        cold[i]=1
        cough[i]=1
        feaver[i]=0
        breating[i]=0
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==13):
        cold[i]=1
        cough[i]=1
        feaver[i]=0
        breating[i]=1
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==14):
        cold[i]=1
        cough[i]=1
        feaver[i]=1
        breating[i]=0
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==15):
        cold[i]=1
        cough[i]=1
        feaver[i]=1
        breating[i]=1
        cronic[i]=1
        age[i]=2
        disease[i]="Medium Risk"
    if(b==15):
        b=1

# %%
# HR3 is 77. It is multiplied with 16. Hence, 77*16=1232. It is from 5175+1232=6407
b=0
for i in range(5287,6519):  #This is to fill   (HR3-->4 in disease column)
    b=b+1
    if(b==1):
        cold[i]=0
        cough[i]=0
        feaver[i]=0
        breating[i]=1
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==2):
        cold[i]=0
        cough[i]=0
        feaver[i]=1
        breating[i]=0
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==3):
        cold[i]=0
        cough[i]=0
        feaver[i]=1
        breating[i]=1
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==4):
        cold[i]=0
        cough[i]=1
        feaver[i]=0
        breating[i]=0
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==5):
        cold[i]=0
        cough[i]=1
        feaver[i]=0
        breating[i]=1
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==6):
        cold[i]=0
        cough[i]=1
        feaver[i]=1
        breating[i]=0
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==7):
        cold[i]=0
        cough[i]=1
        feaver[i]=1
        breating[i]=1
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==8):
        cold[i]=1
        cough[i]=0
        feaver[i]=0
        breating[i]=0
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==9):
        cold[i]=1
        cough[i]=0
        feaver[i]=0
        breating[i]=1
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==10):
        cold[i]=1
        cough[i]=0
        feaver[i]=1
        breating[i]=0
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==11):
        cold[i]=1
        cough[i]=0
        feaver[i]=1
        breating[i]=1
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==12):
        cold[i]=1
        cough[i]=1
        feaver[i]=0
        breating[i]=0
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==13):
        cold[i]=1
        cough[i]=1
        feaver[i]=0
        breating[i]=1
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==14):
        cold[i]=1
        cough[i]=1
        feaver[i]=1
        breating[i]=0
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==15):
        cold[i]=1
        cough[i]=1
        feaver[i]=1
        breating[i]=1
        cronic[i]=1
        age[i]=1
        disease[i]="High Risk"
    if(b==15):
        b=1

# %%
#x.head()
data = pd.DataFrame()
data['cold']=cold
data['cough']=cough
data['feaver']=feaver
data['breating']=breating
data['cronic']=cronic
data['age']=age
data['disease']=disease
#data
#data.head()
    
#c=np.array(data.loc[3, ['cold', 'cough', 'feaver']])
#c.any()
#c.all()
data.to_csv('ds-covid-new-119711-str.csv', index=False, header=True)

# %%
df = pd.read_csv("ds-covid-new-119711-str.csv")
df.sample(5)
# Out:
#         cold  cough  feaver  breating  cronic  age      disease
# 113034     0      0       0         0       0    0  No  Symptom
# 398        0      1       1         0       0    0           GS
# 37524      0      0       0         0       0    0  No  Symptom
# 115742     0      0       0         0       0    0  No  Symptom
# 65492      0      0       0         0       0    0  No  Symptom

# %% [markdown]
# # Accuracy of algorithms before balancing a dataset
#
#
# Add corresponding code in below cells

# %%
df.disease.value_counts() #disease is a field name and it is dependent or output variable
# Out:
# No  Symptom    113192
# GS               2247
# Low Risk         1968
# High Risk        1232
# Medium Risk      1072
# Name: disease, dtype: int64

# %%
df.dtypes
# Out:
# cold         int64
# cough        int64
# feaver       int64
# breating     int64
# cronic       int64
# age          int64
# disease     object
# dtype: object

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import confusion_matrix , classification_report
from tensorflow_addons import losses
from sklearn import metrics
from sklearn.metrics import accuracy_score, f1_score

# %%
X = df.drop('disease',axis='columns')
y = df['disease']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=0)

# %%
y_train.value_counts()
# Out:
# No  Symptom    79200
# GS              1572
# Low Risk        1397
# High Risk        871
# Medium Risk      757
# Name: disease, dtype: int64

# %%
y_test.value_counts()
# Out:
# No  Symptom    33992
# GS               675
# Low Risk         571
# High Risk        361
# Medium Risk      315
# Name: disease, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier as dtc
# gini model
# -------------------------------------
# Model 1) DT with gini index criteria
clf_gini = dtc(criterion = "gini", random_state = 100, max_depth=3,
               min_samples_leaf=5).fit(X_train, y_train)
print(clf_gini)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=5, random_state=100)

# %%
from sklearn.metrics import accuracy_score, f1_score
pred_gini = clf_gini.predict(X_test)
DTTrain=clf_gini.predict(X_train)
print("Gini Testing Accuracy is ", accuracy_score(y_test,pred_gini)*100)
print("Gini Training Accuracy is ", accuracy_score(y_train,DTTrain)*100)
# Out:
# Gini Testing Accuracy is  100.0
# Gini Training Accuracy is  99.99880663985584

# %%
# confusion matrix
cm1=confusion_matrix(y_test, pred_gini)
cm1
# Out:
# array([[  675,     0,     0,     0,     0],
#        [    0,   361,     0,     0,     0],
#        [    0,     0,   571,     0,     0],
#        [    0,     0,     0,   315,     0],
#        [    0,     0,     0,     0, 33992]], dtype=int64)

# %%
# tree visualisation
# list of features (x variables)
features = list(df.columns)
features.remove('disease')
print(features)
# y-variable - classes
classes = df.disease.unique()
print(classes)
# Out:
# ['cold', 'cough', 'feaver', 'breating', 'cronic', 'age']
# ['GS' 'Low Risk' 'Medium Risk' 'High Risk' 'No  Symptom']

# %%
# new implementation to display graph on Console
# right click graph and save
from sklearn import tree
from IPython.display import Image
from io import StringIO
import pydotplus
dot_data = StringIO()
tree.export_graphviz(clf_gini, out_file=dot_data,  
                filled=True, 
                rounded=True, 
                special_characters=True,
                feature_names = features,
                class_names = classes)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
# Entropy model
# -------------------------------------
# Model 1) DT with gini index criteria
clf_entropy = dtc(criterion = "entropy", random_state = 100, max_depth=3,
               min_samples_leaf=5).fit(X_train, y_train)
print(clf_entropy)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=100)

# %%
pred_entropy = clf_entropy.predict(X_test)
EntropyDT=clf_entropy.predict(X_train)
print("Gini Testing Accuracy is ", accuracy_score(y_test,pred_entropy)*100)
print("Gini Training Accuracy is ", accuracy_score(y_train,EntropyDT)*100)
# confusion matrix
cm2=confusion_matrix(y_test,pred_entropy)
cm2
# Out:
# Gini Testing Accuracy is  100.0
# Gini Training Accuracy is  99.99880663985584
# array([[  675,     0,     0,     0,     0],
#        [    0,   361,     0,     0,     0],
#        [    0,     0,   571,     0,     0],
#        [    0,     0,     0,   315,     0],
#        [    0,     0,     0,     0, 33992]], dtype=int64)

# %%
# tree visualisation
# list of features (x variables)
features = list(df.columns)
features.remove('disease')
print(features)
# y-variable - classes
classes = df.disease.unique()
print(classes)
# Out:
# ['cold', 'cough', 'feaver', 'breating', 'cronic', 'age']
# ['GS' 'Low Risk' 'Medium Risk' 'High Risk' 'No  Symptom']

# %%
# new implementation to display graph on Console
# right click graph and save
from sklearn import tree
from IPython.display import Image
from io import StringIO
import pydotplus
dot_data = StringIO()
tree.export_graphviz(clf_entropy, out_file=dot_data,  
                filled=True, 
                rounded=True, 
                special_characters=True,
                feature_names = features,
                class_names = classes)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier(max_depth=10,random_state=101,max_features=None,min_samples_leaf=15)
dtree.fit(X_train, y_train)
y_pred_dtree=dtree.predict(X_test)
dtreetrain=dtree.predict(X_train)
scores=metrics.accuracy_score(y_test, y_pred_dtree)
print("\n DecisionTree: Accuracy of Testing data:",scores)
print("\n DecisionTree: Accuracy of Training data:",accuracy_score(y_train, dtreetrain))
dtree_cm1=confusion_matrix(y_test, y_pred_dtree)
dtree_cm1

dtree_cr = classification_report(y_test, y_pred_dtree)
print("Classification Report:\n",dtree_cr)
# Out:
#  DecisionTree: Accuracy of Testing data: 1.0
#
#  DecisionTree: Accuracy of Training data: 0.9999880663985584
# Classification Report:
#                precision    recall  f1-score   support
#
#           GS       1.00      1.00      1.00       675
#    High Risk       1.00      1.00      1.00       361
#     Low Risk       1.00      1.00      1.00       571
#  Medium Risk       1.00      1.00      1.00       315
#  No  Symptom       1.00      1.00      1.00     33992
#
#     accuracy                           1.00     35914
#    macro avg       1.00      1.00      1.00     35914
# weighted avg       1.00      1.00      1.00     35914

# %% [markdown]
# ### Different Methods for getting balanced dataset
#
# **for getting balanced data set.**
#
# 1. SMOTE -- other forms of SMOTE--such as SMOTE("minority") and SMOTE(sampling_strategy=strategy)
# 2. ADASYN
# 3. SMOTETomek
# 4. SMOTEENN
# 5. RandomUnderSampler
#
# To install imbalanced-learn library use **pip install imbalanced-learn** command
#
# The **stratify** option in train_test_split method gives 1.0 Accuracy. Which is uses as follows:
#
# from sklearn.model_selection import train_test_split
# X_sm_train, X_sm_test, y_sm_train, y_sm_test = train_test_split(X_sm, y_sm, test_size=0.2, random_state=15, stratify=y_sm)
#
# Where as **sometimes** without **stratify** option gives less accuracy for some balanced dataset methods.
#
# from sklearn.model_selection import train_test_split
# X_sm_train, X_sm_test, y_sm_train, y_sm_test = train_test_split(X_sm, y_sm, test_size=0.2, random_state=15)
#
# **The below code executes The RandomUndersampling followed by SMOTE to obtain balanced data set.**

# %%
#!pip install imbalanced-learn

# %%
from imblearn.under_sampling import RandomUnderSampler
#under = RandomUnderSampler()
under = RandomUnderSampler(sampling_strategy='majority')
X_r, y_r=under.fit_sample(X,y)
y_r.value_counts()
# Out:
# GS             2247
# Low Risk       1968
# High Risk      1232
# Medium Risk    1072
# No  Symptom    1072
# Name: disease, dtype: int64

# %%
# RandomUnderSampler followed by either SMOTE or ADASYN
#Python code for SMOTE algorithm
from imblearn.over_sampling import SMOTE
smote=SMOTE()
X_rsm,y_rsm=smote.fit_resample(X_r,y_r)
y_rsm.value_counts()
# Out:
# Low Risk       2247
# No  Symptom    2247
# GS             2247
# High Risk      2247
# Medium Risk    2247
# Name: disease, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_rsm_train, X_rsm_test, y_rsm_train, y_rsm_test = train_test_split(X_r, y_r, test_size=0.3, random_state=15)
y_rsm_test.value_counts()
# Out:
# GS             655
# Low Risk       607
# High Risk      377
# No  Symptom    338
# Medium Risk    301
# Name: disease, dtype: int64

# %%
y_rsm_train.value_counts()
# Out:
# GS             1592
# Low Risk       1361
# High Risk       855
# Medium Risk     771
# No  Symptom     734
# Name: disease, dtype: int64

# %%
# tree visualisation
# list of features (x variables)
features = list(df.columns)
features.remove('disease')
print(features)
# y-variable - classes
classes = df.disease.unique()
print(classes)
# Out:
# ['cold', 'cough', 'feaver', 'breating', 'cronic', 'age']
# ['GS' 'Low Risk' 'Medium Risk' 'High Risk' 'No  Symptom']

# %%
# gini model
# -------------------------------------
# Model 1) DT with gini index criteria
rsm_clf_gini = dtc(criterion = "gini", random_state = 100, max_depth=3,
               min_samples_leaf=5).fit(X_rsm_train, y_rsm_train)
print(rsm_clf_gini)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=5, random_state=100)

# %%
# new implementation to display graph on Console
# right click graph and save
from sklearn import tree
from IPython.display import Image
from io import StringIO
import pydotplus
dot_data = StringIO()
tree.export_graphviz(rsm_clf_gini, out_file=dot_data,  
                filled=True, 
                rounded=True, 
                special_characters=True,
                feature_names = features,
                class_names = classes)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %%
#from sklearn.metrics import accuracy_score, f1_score
rsm_pred_gini = rsm_clf_gini.predict(X_rsm_test)
#smote_pred_gini.value_counts()
#print("Gini Accuracy is ", accuracy_score(y_rsm_test,rsm_pred_gini)*100)
giniTrain=rsm_clf_gini.predict(X_rsm_train)
print("\n The Gini: Accuracy of Training data:",accuracy_score(y_rsm_train,giniTrain))
print("\n The Gini: Accuracy of Testing data:",accuracy_score(y_rsm_test,rsm_pred_gini)*100)
# Out:
#  The Gini: Accuracy of Training data: 0.9998117824204781
#
#  The Gini: Accuracy of Testing data: 100.0

# %%
# confusion matrix
gini_rsm_cm1=confusion_matrix(y_rsm_test, rsm_pred_gini)
gini_rsm_cm1
# Out:
# array([[655,   0,   0,   0,   0],
#        [  0, 377,   0,   0,   0],
#        [  0,   0, 607,   0,   0],
#        [  0,   0,   0, 301,   0],
#        [  0,   0,   0,   0, 338]], dtype=int64)

# %%
# Entropy model
# -------------------------------------
# Model 1) DT with gini index criteria
clfentropy = dtc(criterion = "entropy", random_state = 100, max_depth=3,
               min_samples_leaf=5).fit(X_train, y_train)
print(clfentropy)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, min_samples_leaf=5,
#                        random_state=100)

# %%
predentropy = clfentropy.predict(X_test)
Entropy_DT=clfentropy.predict(X_train)
print("Gini Testing Accuracy is ", accuracy_score(y_test,predentropy)*100)
print("Gini Training Accuracy is ", accuracy_score(y_train,Entropy_DT)*100)
# confusion matrix
cm2=confusion_matrix(y_test,predentropy)
cm2
# Out:
# Gini Testing Accuracy is  100.0
# Gini Training Accuracy is  99.99880663985584
# array([[  675,     0,     0,     0,     0],
#        [    0,   361,     0,     0,     0],
#        [    0,     0,   571,     0,     0],
#        [    0,     0,     0,   315,     0],
#        [    0,     0,     0,     0, 33992]], dtype=int64)

# %%
# tree visualisation
# list of features (x variables)
features = list(df.columns)
features.remove('disease')
print(features)
# y-variable - classes
classes = df.disease.unique()
print(classes)
# Out:
# ['cold', 'cough', 'feaver', 'breating', 'cronic', 'age']
# ['GS' 'Low Risk' 'Medium Risk' 'High Risk' 'No  Symptom']

# %%
# new implementation to display graph on Console
# right click graph and save
from sklearn import tree
from IPython.display import Image
from io import StringIO
import pydotplus
dot_data = StringIO()
tree.export_graphviz(clfentropy, out_file=dot_data,  
                filled=True, 
                rounded=True, 
                special_characters=True,
                feature_names = features,
                class_names = classes)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
